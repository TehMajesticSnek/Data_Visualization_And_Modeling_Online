# %% [markdown]
# # Lab Instructions
#
# You have been hired by a record executive to design a guaranteed smash hit song based on data.  The exec has decided that if you make a song that has all the most popular features of recent songs then it will definitely be a hit.  So if - for example - the most common key in the Spotify data is C# then we would want the song we are designing to also be in C#.  If a "typical" value of BPM is between 120 and 130 then we would want the song we are designing to also have a tempo between 120 and 130 BMP.
#
# Visualize and describe the distribution of:
# * BPM
# * Key
# * Mode
# * Danceability
# * Energy
# * Speechiness
# * Acousticness
#
# Based on your visualizations and calculations, what values for each of these features would make a song a guaranteed smash hit?  For quantitative features, you should propose a range of values.
#
# Use a large language model to help you write code to identify if there are any songs in the Spotify dataset that meet all of the criteria we determined.  What is/are the artist(s) and title(s) of the song?  Were any of these songs actually popular?
#
# Pick a song that you know was a smash hit. How do the values of BPM, key, mode, danceability, etc. compare to other songs?
#
# **Hint:**  Import the Spotify data using `df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')`.

# %%
import pandas as pd
df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')
df.head(25)
# Out:
#                                            track_name  \
# 0                 Seven (feat. Latto) (Explicit Ver.)
# 1                                                LALA
# 2                                             vampire
# 3                                        Cruel Summer
# 4                                      WHERE SHE GOES
# 5                                            Sprinter
# 6                                     Ella Baila Sola
# 7                                            Columbia
# 8                                            fukumean
# 9                                     La Bebe - Remix
# 10                                          un x100to
# 11                                          Super Shy
# 12                                            Flowers
# 13                                           Daylight
# 14                                          As It Was
# 15                                          Kill Bill
# 16                                  Cupid - Twin Ver.
# 17  What Was I Made For? [From The Motion Picture ...
# 18                                         Classy 101
# 19                                         Like Crazy
# 20                                          LADY GAGA
# 21  I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...
# 22                                   I Wanna Be Yours
# 23           Peso Pluma: Bzrp Music Sessions, Vol. 55
# 24  Popular (with Playboi Carti & Madonna) - The I...
#
#                               artist(s)_name  artist_count  released_year  \
# 0                           Latto, Jung Kook             2           2023
# 1                                Myke Towers             1           2023
# 2                             Olivia Rodrigo             1           2023
# 3                               Taylor Swift             1           2019
# 4                                  Bad Bunny             1           2023
# 5                          Dave, Central Cee             2           2023
# 6                 Eslabon Armado, Peso Pluma             2           2023
# 7                                    Quevedo             1           2023
# 8                                      Gunna             1           2023
# 9                      Peso Pluma, Yng Lvcas             2           2023
# 10                 Bad Bunny, Grupo Frontera             2           2023
# 11                                  NewJeans             1           2023
# 12                               Miley Cyrus             1           2023
# 13                             David Kushner             1           2023
# 14                              Harry Styles             1           2022
# 15                                       SZA             1           2022
# 16                               Fifty Fifty             1           2023
# 17                             Billie Eilish             1           2023
# 18                          Feid, Young Miko             2           2023
# 19                                     Jimin             1           2023
# 20  Gabito Ballesteros, Junior H, Peso Pluma             3           2023
# 21                              Taylor Swift             1           2023
# 22                            Arctic Monkeys             1           2013
# 23                      Bizarrap, Peso Pluma             2           2023
# 24        The Weeknd, Madonna, Playboi Carti             3           2023
#
#     released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 0                7            14                   553                147
# 1                3            23                  1474                 48
# 2                6            30                  1397                113
# 3                8            23                  7858                100
# 4                5            18                  3133                 50
# 5                6             1                  2186                 91
# 6                3            16                  3090                 50
# 7                7             7                   714                 43
# 8                5            15                  1096                 83
# 9                3            17                  2953                 44
# 10               4            17                  2876                 40
# 11               7             7                   422                 55
# 12               1            12                 12211                115
# 13               4            14                  3528                 98
# 14               3            31                 23575                130
# 15              12             8                  8109                 77
# 16               2            24                  2942                 77
# 17               7            13                   873                104
# 18               3            31                  2610                 40
# 19               3            24                   596                 68
# 20               6            22                   332                 26
# 21               7             7                   516                 38
# 22               1             1                 12859                110
# 23               5            31                  1313                 40
# 24               6             2                  1945                 87
#
#        streams  in_apple_playlists  ...  bpm  key   mode danceability_%  \
# 0    141381703                  43  ...  125    B  Major             80
# 1    133716286                  48  ...   92   C#  Major             71
# 2    140003974                  94  ...  138    F  Major             51
# 3    800840817                 116  ...  170    A  Major             55
# 4    303236322                  84  ...  144    A  Minor             65
# 5    183706234                  67  ...  141   C#  Major             92
# 6    725980112                  34  ...  148    F  Minor             67
# 7     58149378                  25  ...  100    F  Major             67
# 8     95217315                  60  ...  130   C#  Minor             85
# 9    553634067                  49  ...  170    D  Minor             81
# 10   505671438                  41  ...   83   F#  Minor             57
# 11    58255150                  37  ...  150    F  Minor             78
# 12  1316855716                 300  ...  118  NaN  Major             71
# 13   387570742                  80  ...  130    D  Minor             51
# 14  2513188493                 403  ...  174   F#  Minor             52
# 15  1163093654                 183  ...   89   G#  Major             64
# 16   496795686                  91  ...  120    B  Minor             78
# 17    30546883                  80  ...   78  NaN  Major             44
# 18   335222234                  43  ...  100    B  Major             86
# 19   363369738                   8  ...  120    G  Major             63
# 20    86444842                  11  ...  140    F  Minor             65
# 21    52135248                  73  ...  123   F#  Major             69
# 22  1297026226                  24  ...  135  NaN  Minor             48
# 23   200647221                  17  ...  133    F  Minor             85
# 24   115364561                  74  ...   99   C#  Major             85
#
#     valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 0          89       83             31                   0           8
# 1          61       74              7                   0          10
# 2          32       53             17                   0          31
# 3          58       72             11                   0          11
# 4          23       80             14                  63          11
# 5          66       58             19                   0           8
# 6          83       76             48                   0           8
# 7          26       71             37                   0          11
# 8          22       62             12                   0          28
# 9          56       48             21                   0           8
# 10         56       72             23                   0          27
# 11         52       82             18                   0          15
# 12         65       68              6                   0           3
# 13         32       43             83                   0           9
# 14         66       73             34                   0          31
# 15         43       73              5                  17          16
# 16         76       59             43                   0          34
# 17         14        9             96                   0          10
# 18         67       66             14                   0          12
# 19         36       73              0                   0          36
# 20         87       74             22                   0          42
# 21         82       76              6                   0           6
# 22         44       42             12                   2          11
# 23         81       67             26                   0          12
# 24         83       68              7                   0          36
#
#     speechiness_%
# 0               4
# 1               4
# 2               6
# 3              15
# 4               6
# 5              24
# 6               3
# 7               4
# 8               9
# 9              33
# 10              5
# 11              7
# 12              7
# 13              3
# 14              6
# 15              4
# 16              3
# 17              3
# 18             16
# 19              4
# 20              4
# 21              3
# 22              3
# 23              5
# 24             20
#
# [25 rows x 24 columns]

# %%
df['bpm'].plot(kind='hist', title='BPM')
# Out:
# <Axes: title={'center': 'BPM'}, ylabel='Frequency'>

# %%
df['key'].value_counts().plot(kind='bar', title='Key')
# Out:
# <Axes: title={'center': 'Key'}, xlabel='key'>

# %%
df['mode'].value_counts().plot(kind='bar', title='Mode')
# Out:
# <Axes: title={'center': 'Mode'}, xlabel='mode'>

# %%
df['danceability_%'].plot(kind='hist', title='Danceability')
# Out:
# <Axes: title={'center': 'Danceability'}, ylabel='Frequency'>

# %%
df['energy_%'].plot(kind='hist', title='Energy')
# Out:
# <Axes: title={'center': 'Energy'}, ylabel='Frequency'>

# %%
df['speechiness_%'].plot(kind='hist', title='Speechiness')
# Out:
# <Axes: title={'center': 'Speechiness'}, ylabel='Frequency'>

# %%
df['acousticness_%'].plot(kind='hist', title='Acousticness')
# Out:
# <Axes: title={'center': 'Acousticness'}, ylabel='Frequency'>

# %%
#BPM = 120-130
#Key = C#
#Mode = Major
#Danceability = 70-80%
#Energy = 70-80%
#Speechiness = 0-10%
#Acousticness = 0-10%

# %%
filtered = df[(df['bpm'] >= 120) & (df['bpm'] <=130) &
    (df['key'] == 'C#') &
    (df['mode'] == 'Major') &
    (df['danceability_%'] >= 70) & (df['danceability_%'] <= 80) &
    (df['energy_%'] >= 70) & (df['energy_%'] <= 80) &
    (df['speechiness_%'] >= 0) & (df['speechiness_%'] <= 10) &
    (df['acousticness_%'] >= 0) & (df['acousticness_%'] <= 10)]
filtered.head()
#Yes, they are quite popular according to the stream count.
# Out:
#                                        track_name            artist(s)_name  \
# 168                                 We Found Love    Rihanna, Calvin Harris
# 236  AMERICA HAS A PROBLEM (feat. Kendrick Lamar)  Kendrick Lamar, Beyoncï¿
#
#      artist_count  released_year  released_month  released_day  \
# 168             2           2011               1             1
# 236             2           2023               5            19
#
#      in_spotify_playlists  in_spotify_charts     streams  in_apple_playlists  \
# 168                 36843                 21  1235005533                 321
# 236                   896                  0    57089066                  34
#
#      ...  bpm key   mode danceability_%  valence_% energy_% acousticness_%  \
# 168  ...  128  C#  Major             73         60       77              3
# 236  ...  126  C#  Major             78         20       70              1
#
#      instrumentalness_%  liveness_%  speechiness_%
# 168                   0          11              4
# 236                   0          16              4
#
# [2 rows x 24 columns]

# %%
hit = df[df['track_name'] == 'Bad Habits']
hit.head()
#Similar to 'typical' values are bpm, acousicness, and speechiness.
#Key, Mode, danceability, and energy values aren't overly similar to other songs.
# Out:
#      track_name artist(s)_name  artist_count  released_year  released_month  \
# 429  Bad Habits     Ed Sheeran             1           2020               9
#
#      released_day  in_spotify_playlists  in_spotify_charts     streams  \
# 429             3                 12755                  8  1555511105
#
#      in_apple_playlists  ...  bpm key   mode danceability_%  valence_%  \
# 429                 344  ...  126   B  Minor             81         59
#
#     energy_% acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 429       90              5                   0          36              3
#
# [1 rows x 24 columns]
